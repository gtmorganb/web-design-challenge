# %%
import pandas as pd

# %%
#load file to read 
city_data = "city.csv"

#read file 
city_data_read = pd.read_csv(city_data)

#make dataframe
city_df = pd.DataFrame(city_data_read)
city_df.head()
# Out:
#    City ID        City  Cloudiness Country        Date  Humidity  Latitude  \
# 0        0       Bluff         100      NZ  1637586683        69  -46.6000
# 1        1  Bredasdorp         100      ZA  1637586683        80  -34.5322
# 2        2   Dongsheng           6      CN  1637586684        20   39.8161
# 3        3     Rikitea          89      PF  1637586508        72  -23.1203
# 4        4   Bathsheba          40      BB  1637586684        62   13.2167
#
#    Longitude  Max Temp  Wind Speed
# 0   168.3333     50.70        7.34
# 1    20.0403     63.93       11.56
# 2   109.9776     20.71        7.58
# 3  -134.9692     74.17        8.01
# 4   -59.5167     86.61       16.11

# %%
city_html = pd.DataFrame.to_html(city_df)
print(city_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City ID</th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Bluff</td>
#       <td>100</td>
#       <td>NZ</td>
#       <td>1637586683</td>
#       <td>69</td>
#       <td>-46.6000</td>
#       <td>168.3333</td>
#       <td>50.70</td>
#       <td>7.34</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Bredasdorp</td>
#       <td>100</td>
#       <td>ZA</td>
#       <td>1637586683</td>
#       <td>80</td>
#       <td>-34.5322</td>
#       <td>20.0403</td>
#       <td>63.93</td>
#       <td>11.56</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...
